# %%
import numpy as np
import h5py
from fake_spectra.plot_spectra import PlottingSpectra
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
for i in range(14):
    ps = PlottingSpectra(num=i,base="output", label="My label",savefile="gridded_spectra.hdf5")
    ps.plot_cddf("H",1)
# Out:
# Reading pre-computed spectra (from file output/SPECTRA_000/gridded_spectra.hdf5  )
# ...
# 100  sightlines. resolution:  3.7510381517144262  z= 49.0
# Reading pre-computed spectra (from file output/SPECTRA_001/gridded_spectra.hdf5  )
# ...
# 100  sightlines. resolution:  1.679638604850015  z= 8.999999999999998
# Reading pre-computed spectra (from file output/SPECTRA_002/gridded_spectra.hdf5  )
# 100  sightlines. resolution:  1.220596364061605  z= 4.199999999991681
# Reading pre-computed spectra (from file output/SPECTRA_003/gridded_spectra.hdf5  )
# 100  sightlines. resolution:  1.1982253210689222  z= 4.0
# Reading pre-computed spectra (from file output/SPECTRA_004/gridded_spectra.hdf5  )
# 100  sightlines. resolution:  1.1755463124894219  z= 3.80000000000768
# Reading pre-computed spectra (from file output/SPECTRA_005/gridded_spectra.hdf5  )
# 100  sightlines. resolution:  1.1525625351374436  z= 3.59999999999632
# ...

# %%
ps = PlottingSpectra(num=13,base="output", label="My label",savefile="gridded_spectra.hdf5")
ps.plot_cddf("H",1)
# Out:
# Reading pre-computed spectra (from file output/SPECTRA_013/gridded_spectra.hdf5  )
# 100  sightlines. resolution:  0.9612758712574349  z= 2.0000300003000033

# %%
from fake_spectra.tempdens import fit_td_rel_plot

for i in range(14):
    fit_td_rel_plot(i, "output", plot=True)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/fake_spectra/abstractsnapshot.py:20, in AbstractSnapshotFactory(num, base, comm)
#      19 try:
# ---> 20     return HDF5Snapshot(num, base, comm)
#      21 except IOError:
#
# File ~/miniconda3/lib/python3.13/site-packages/fake_spectra/abstractsnapshot.py:161, in HDF5Snapshot.__init__(self, num, base, comm)
#     160 self.comm = comm
# --> 161 self._files = sorted(self._get_all_files(num, base))
#     162 self._files.reverse()
#
# File ~/miniconda3/lib/python3.13/site-packages/fake_spectra/abstractsnapshot.py:192, in HDF5Snapshot._get_all_files(self, num, base)
#     191 if len(fnames) == 0:
# --> 192     raise IOError("No files found")
#     193 fnames.sort()
#
# OSError: No files found
#
# During handling of the above exception, another exception occurred:
#
# ...
